# %% [markdown]
# # Cases B and C: KvN-QSVT

# %%
from pathlib import Path
from qsvt_phase_generation_1D import main as generate_phases
from simulation_1D import CASE_B, CASE_C, run_case
if not Path('output/qsvt_phases/cos1x_R5.csv').exists():
    generate_phases()
records = []
for case in CASE_B + CASE_C:
    _, metadata, _ = run_case(case, 'qsvt', progress=True)
    records.append(metadata)
records
